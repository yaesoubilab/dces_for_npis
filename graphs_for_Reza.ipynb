# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib.lines import Line2D

FIG_SIZE = (10, 5)
WTP_X_RANGE = (-200, 200)
MARKER_SIZE = 7
INCLUDE_VACCINE = False

# %% [markdown]
# Read in files

# %%
results_no_vaccine = pd.read_csv('estimates/results_drop_first_level_no_vaccine_WTP.csv', index_col= 0)
results_vaccine = pd.read_csv('estimates/results_drop_first_level_vaccine_WTP.csv', index_col= 0)


results_political_no_vaccine = pd.read_csv('estimates/results_political_no_vaccine.csv', index_col= 0)
results_gender_no_vaccine = pd.read_csv('estimates/results_gender_no_vaccine.csv', index_col= 0)
results_age_no_vaccine = pd.read_csv('estimates/results_age_no_vaccine.csv', index_col= 0)
results_income_no_vaccine = pd.read_csv('estimates/results_income_no_vaccine.csv', index_col= 0)
results_chronic_no_vaccine = pd.read_csv('estimates/results_chronic_no_vaccine.csv', index_col= 0)
results_race_no_vaccine = pd.read_csv('estimates/results_race_no_vaccine.csv', index_col= 0)
results_child_no_vaccine = pd.read_csv('estimates/results_child_no_vaccine.csv', index_col= 0)
results_vaccination_no_vaccine = pd.read_csv('estimates/results_vaccination_no_vaccine.csv', index_col= 0)

results_political_vaccine = pd.read_csv('estimates/results_political_vaccine.csv', index_col= 0)
results_gender_vaccine = pd.read_csv('estimates/results_gender_vaccine.csv', index_col= 0)
results_age_vaccine = pd.read_csv('estimates/results_age_vaccine.csv', index_col= 0)
results_income_vaccine = pd.read_csv('estimates/results_income_vaccine.csv', index_col= 0)
results_chronic_vaccine = pd.read_csv('estimates/results_chronic_vaccine.csv', index_col= 0)
results_race_vaccine = pd.read_csv('estimates/results_race_vaccine.csv', index_col= 0)
results_child_vaccine = pd.read_csv('estimates/results_child_vaccine.csv', index_col= 0)
results_vaccination_vaccine = pd.read_csv('estimates/results_vaccination_vaccine.csv', index_col= 0)

# %% [markdown]
# Multiply by 100 to get WTA

# %%
results_vaccine['WTP_CI_lower'] = results_vaccine['WTP_CI_lower']*100
results_vaccine['WTP_CI_upper'] = results_vaccine['WTP_CI_upper']*100
results_no_vaccine['WTP_CI_lower'] = results_no_vaccine['WTP_CI_lower']*100

results_no_vaccine['WTP_CI_upper'] = results_no_vaccine['WTP_CI_upper']*100
results_vaccine['WTP_mean'] = results_vaccine['WTP_mean']*100
results_no_vaccine['WTP_mean'] = results_no_vaccine['WTP_mean']*100

results_political_no_vaccine['WTP_CI_lower'] = results_political_no_vaccine['WTP_CI_lower']*100
results_political_no_vaccine['WTP_CI_upper'] = results_political_no_vaccine['WTP_CI_upper']*100
results_political_no_vaccine['WTP_mean'] = results_political_no_vaccine['WTP_mean']*100

results_political_vaccine['WTP_CI_lower'] = results_political_vaccine['WTP_CI_lower']*100
results_political_vaccine['WTP_CI_upper'] = results_political_vaccine['WTP_CI_upper']*100
results_political_vaccine['WTP_mean'] = results_political_vaccine['WTP_mean']*100

results_gender_no_vaccine['WTP_CI_lower'] = results_gender_no_vaccine['WTP_CI_lower']*100
results_gender_no_vaccine['WTP_CI_upper'] = results_gender_no_vaccine['WTP_CI_upper']*100
results_gender_no_vaccine['WTP_mean'] = results_gender_no_vaccine['WTP_mean']*100

results_gender_vaccine['WTP_CI_lower'] = results_gender_vaccine['WTP_CI_lower']*100
results_gender_vaccine['WTP_CI_upper'] = results_gender_vaccine['WTP_CI_upper']*100
results_gender_vaccine['WTP_mean'] = results_gender_vaccine['WTP_mean']*100

results_age_no_vaccine['WTP_CI_lower'] = results_age_no_vaccine['WTP_CI_lower']*100
results_age_no_vaccine['WTP_CI_upper'] = results_age_no_vaccine['WTP_CI_upper']*100
results_age_no_vaccine['WTP_mean'] = results_age_no_vaccine['WTP_mean']*100

results_age_vaccine['WTP_CI_lower'] = results_age_vaccine['WTP_CI_lower']*100
results_age_vaccine['WTP_CI_upper'] = results_age_vaccine['WTP_CI_upper']*100
results_age_vaccine['WTP_mean'] = results_age_vaccine['WTP_mean']*100

results_income_no_vaccine['WTP_CI_lower'] = results_income_no_vaccine['WTP_CI_lower']*100
results_income_no_vaccine['WTP_CI_upper'] = results_income_no_vaccine['WTP_CI_upper']*100
results_income_no_vaccine['WTP_mean'] = results_income_no_vaccine['WTP_mean']*100

results_income_vaccine['WTP_CI_lower'] = results_income_vaccine['WTP_CI_lower']*100
results_income_vaccine['WTP_CI_upper'] = results_income_vaccine['WTP_CI_upper']*100
results_income_vaccine['WTP_mean'] = results_income_vaccine['WTP_mean']*100

results_chronic_no_vaccine['WTP_CI_lower'] = results_chronic_no_vaccine['WTP_CI_lower']*100
results_chronic_no_vaccine['WTP_CI_upper'] = results_chronic_no_vaccine['WTP_CI_upper']*100
results_chronic_no_vaccine['WTP_mean'] = results_chronic_no_vaccine['WTP_mean']*100

results_chronic_vaccine['WTP_CI_lower'] = results_chronic_vaccine['WTP_CI_lower']*100
results_chronic_vaccine['WTP_CI_upper'] = results_chronic_vaccine['WTP_CI_upper']*100
results_chronic_vaccine['WTP_mean'] = results_chronic_vaccine['WTP_mean']*100

results_race_no_vaccine['WTP_CI_lower'] = results_race_no_vaccine['WTP_CI_lower']*100
results_race_no_vaccine['WTP_CI_upper'] = results_race_no_vaccine['WTP_CI_upper']*100
results_race_no_vaccine['WTP_mean'] = results_race_no_vaccine['WTP_mean']*100

results_race_vaccine['WTP_CI_lower'] = results_race_vaccine['WTP_CI_lower']*100
results_race_vaccine['WTP_CI_upper'] = results_race_vaccine['WTP_CI_upper']*100
results_race_vaccine['WTP_mean'] = results_race_vaccine['WTP_mean']*100

results_child_no_vaccine['WTP_CI_lower'] = results_child_no_vaccine['WTP_CI_lower'] * 100
results_child_no_vaccine['WTP_CI_upper'] = results_child_no_vaccine['WTP_CI_upper'] * 100
results_child_no_vaccine['WTP_mean'] = results_child_no_vaccine['WTP_mean'] * 100

results_child_vaccine['WTP_CI_lower'] = results_child_vaccine['WTP_CI_lower'] * 100
results_child_vaccine['WTP_CI_upper'] = results_child_vaccine['WTP_CI_upper'] * 100
results_child_vaccine['WTP_mean'] = results_child_vaccine['WTP_mean'] * 100

results_vaccination_no_vaccine['WTP_CI_lower'] = results_vaccination_no_vaccine['WTP_CI_lower'] * 100
results_vaccination_no_vaccine['WTP_CI_upper'] = results_vaccination_no_vaccine['WTP_CI_upper'] * 100
results_vaccination_no_vaccine['WTP_mean'] = results_vaccination_no_vaccine['WTP_mean'] * 100

results_vaccination_vaccine['WTP_CI_lower'] = results_vaccination_vaccine['WTP_CI_lower'] * 100
results_vaccination_vaccine['WTP_CI_upper'] = results_vaccination_vaccine['WTP_CI_upper'] * 100
results_vaccination_vaccine['WTP_mean'] = results_vaccination_vaccine['WTP_mean'] * 100

# %% [markdown]
# Plotting params

# %%
x_lab_coef = ["Crowded indoor venues closed", "Non-essential businesses close", "Masks required only in schools", "Masks required in public", "Masks required in all indoor spaces", "High schools close with remote learning", "High schools close, no remote learning", "All schools close with remote learning", "All schools close, no remote learning", "50% reduction in transit capacity", "Restricted primary care", "Restricted primary and optional care", "Number of infections"]
x_lab_wtp = ["Crowded indoor venues closed", "Non-essential businesses close", "Masks required only in schools", "Masks required in public", "Masks required in all indoor spaces", "High schools close with remote learning", "High schools close, no remote learning", "All schools close with remote learning", "All schools close, no remote learning", "50% reduction in transit capacity", "", "", ""]
x_lab_single_plots = ["Crowded indoor venues closed", "Non-essential businesses close", "Masks required only in schools", "Masks required in public", "Masks required in all indoor spaces", "High schools close with remote learning", "High schools close, no remote learning", "All schools close with remote learning", "All schools close, no remote learning", "50% reduction in transit capacity"]

# %% [markdown]
# Shortcut to reorder indices

# %%
reorder_indices = [
    'Business_closures_2', 'Business_closures_3', 'Mask_mandates_2', 'Mask_mandates_3',
    'Mask_mandates_4', 'School_closures_2', 'School_closures_3', 'School_closures_4',
    'School_closures_5', 'Transit_2', 'Healthcare_restrictions_2', 'Healthcare_restrictions_3',
    'Number_of_infections'
]

reorder_indices_gender = [
    'Business_closures_2', 'Business_closures_2_Male', 'Business_closures_3', 'Business_closures_3_Male',
    'Mask_mandates_2', 'Mask_mandates_2_Male', 'Mask_mandates_3', 'Mask_mandates_3_Male', 'Mask_mandates_4', 
    'Mask_mandates_4_Male', 'School_closures_2', 'School_closures_2_Male', 'School_closures_3', 
    'School_closures_3_Male', 'School_closures_4', 'School_closures_4_Male', 'School_closures_5', 
    'School_closures_5_Male', 'Transit_2', 'Transit_2_Male', 'Healthcare_restrictions_2', 
    'Healthcare_restrictions_2_Male', 'Healthcare_restrictions_3', 'Healthcare_restrictions_3_Male', 
    'Number_of_infections', 'Number_of_infections_Male'
]

reorder_indices_political = [
    'Business_closures_2', 'Business_closures_2_Independent', 'Business_closures_2_Other', 'Business_closures_2_Republican',
    'Business_closures_3', 'Business_closures_3_Independent', 'Business_closures_3_Other', 'Business_closures_3_Republican',
    'Mask_mandates_2', 'Mask_mandates_2_Independent', 'Mask_mandates_2_Other', 'Mask_mandates_2_Republican', 
    'Mask_mandates_3', 'Mask_mandates_3_Independent', 'Mask_mandates_3_Other', 'Mask_mandates_3_Republican', 
    'Mask_mandates_4', 'Mask_mandates_4_Independent', 'Mask_mandates_4_Other', 'Mask_mandates_4_Republican',
    'School_closures_2', 'School_closures_2_Independent', 'School_closures_2_Other', 'School_closures_2_Republican', 
    'School_closures_3', 'School_closures_3_Independent', 'School_closures_3_Other', 'School_closures_3_Republican', 
    'School_closures_4', 'School_closures_4_Independent', 'School_closures_4_Other', 'School_closures_4_Republican', 
    'School_closures_5', 'School_closures_5_Independent', 'School_closures_5_Other', 'School_closures_5_Republican', 
    'Transit_2', 'Transit_2_Independent', 'Transit_2_Other', 'Transit_2_Republican', 
    'Healthcare_restrictions_2', 'Healthcare_restrictions_2_Independent', 'Healthcare_restrictions_2_Other', 
    'Healthcare_restrictions_2_Republican', 'Healthcare_restrictions_3', 'Healthcare_restrictions_3_Independent', 
    'Healthcare_restrictions_3_Other', 'Healthcare_restrictions_3_Republican', 'Number_of_infections', 
    'Number_of_infections_Independent', 'Number_of_infections_Other', 'Number_of_infections_Republican'
]

reorder_indices_age = [
    'Business_closures_2', 'Business_closures_2_25-34', 'Business_closures_2_35-49', 'Business_closures_2_50-64', 
    'Business_closures_2_≥ 65', 'Business_closures_3', 'Business_closures_3_25-34', 'Business_closures_3_35-49', 
    'Business_closures_3_50-64', 'Business_closures_3_≥ 65', 'Mask_mandates_2', 'Mask_mandates_2_25-34', 
    'Mask_mandates_2_35-49', 'Mask_mandates_2_50-64', 'Mask_mandates_2_≥ 65', 'Mask_mandates_3', 
    'Mask_mandates_3_25-34', 'Mask_mandates_3_35-49', 'Mask_mandates_3_50-64', 'Mask_mandates_3_≥ 65', 
    'Mask_mandates_4', 'Mask_mandates_4_25-34', 'Mask_mandates_4_35-49', 'Mask_mandates_4_50-64', 
    'Mask_mandates_4_≥ 65', 'School_closures_2', 'School_closures_2_25-34', 'School_closures_2_35-49', 
    'School_closures_2_50-64', 'School_closures_2_≥ 65', 'School_closures_3', 'School_closures_3_25-34', 
    'School_closures_3_35-49', 'School_closures_3_50-64', 'School_closures_3_≥ 65', 'School_closures_4', 
    'School_closures_4_25-34', 'School_closures_4_35-49', 'School_closures_4_50-64', 'School_closures_4_≥ 65', 
    'School_closures_5', 'School_closures_5_25-34', 'School_closures_5_35-49', 'School_closures_5_50-64', 
    'School_closures_5_≥ 65', 'Transit_2', 'Transit_2_25-34', 'Transit_2_35-49', 'Transit_2_50-64', 
    'Transit_2_≥ 65', 'Healthcare_restrictions_2', 'Healthcare_restrictions_2_25-34', 'Healthcare_restrictions_2_35-49', 
    'Healthcare_restrictions_2_50-64', 'Healthcare_restrictions_2_≥ 65', 'Healthcare_restrictions_3', 
    'Healthcare_restrictions_3_25-34', 'Healthcare_restrictions_3_35-49', 'Healthcare_restrictions_3_50-64', 
    'Healthcare_restrictions_3_≥ 65', 'Number_of_infections', 'Number_of_infections_25-34', 'Number_of_infections_35-49', 
    'Number_of_infections_50-64', 'Number_of_infections_≥ 65'
]

reorder_indices_chronic = [
    'Business_closures_2', 'Business_closures_2_No', 'Business_closures_2_Prefer not to answer',
    'Business_closures_3', 'Business_closures_3_No', 'Business_closures_3_Prefer not to answer',
    'Mask_mandates_2', 'Mask_mandates_2_No', 'Mask_mandates_2_Prefer not to answer',
    'Mask_mandates_3', 'Mask_mandates_3_No', 'Mask_mandates_3_Prefer not to answer',
    'Mask_mandates_4', 'Mask_mandates_4_No', 'Mask_mandates_4_Prefer not to answer',
    'School_closures_2', 'School_closures_2_No', 'School_closures_2_Prefer not to answer',
    'School_closures_3', 'School_closures_3_No', 'School_closures_3_Prefer not to answer',
    'School_closures_4', 'School_closures_4_No', 'School_closures_4_Prefer not to answer',
    'School_closures_5', 'School_closures_5_No', 'School_closures_5_Prefer not to answer',
    'Transit_2', 'Transit_2_No', 'Transit_2_Prefer not to answer',
    'Healthcare_restrictions_2', 'Healthcare_restrictions_2_No', 'Healthcare_restrictions_2_Prefer not to answer',
    'Healthcare_restrictions_3', 'Healthcare_restrictions_3_No', 'Healthcare_restrictions_3_Prefer not to answer',
    'Number_of_infections', 'Number_of_infections_No', 'Number_of_infections_Prefer not to answer'
]

reorder_indices_race = ['Business_closures_2',
       'Business_closures_2_Asian/Asian American or Chinese or Vietnamese or Filipino or Japanese or Asian Indian',
       'Business_closures_2_Middle Eastern of North African',
       'Business_closures_2_Native Hawaiian or Pacific Islander or American Indian or Native American or Alaskan Native or Chamoan or Samoan',
       'Business_closures_2_Other or Self-defined or Multi-racial',
       'Business_closures_2_White', 'Business_closures_3',
       'Business_closures_3_Asian/Asian American or Chinese or Vietnamese or Filipino or Japanese or Asian Indian',
       'Business_closures_3_Middle Eastern of North African',
       'Business_closures_3_Native Hawaiian or Pacific Islander or American Indian or Native American or Alaskan Native or Chamoan or Samoan',
       'Business_closures_3_Other or Self-defined or Multi-racial',
       'Business_closures_3_White', 'Mask_mandates_2',
       'Mask_mandates_2_Asian/Asian American or Chinese or Vietnamese or Filipino or Japanese or Asian Indian',
       'Mask_mandates_2_Middle Eastern of North African',
       'Mask_mandates_2_Native Hawaiian or Pacific Islander or American Indian or Native American or Alaskan Native or Chamoan or Samoan',
       'Mask_mandates_2_Other or Self-defined or Multi-racial',
       'Mask_mandates_2_White', 'Mask_mandates_3',
       'Mask_mandates_3_Asian/Asian American or Chinese or Vietnamese or Filipino or Japanese or Asian Indian',
       'Mask_mandates_3_Middle Eastern of North African',
       'Mask_mandates_3_Native Hawaiian or Pacific Islander or American Indian or Native American or Alaskan Native or Chamoan or Samoan',
       'Mask_mandates_3_Other or Self-defined or Multi-racial',
       'Mask_mandates_3_White', 'Mask_mandates_4',
       'Mask_mandates_4_Asian/Asian American or Chinese or Vietnamese or Filipino or Japanese or Asian Indian',
       'Mask_mandates_4_Middle Eastern of North African',
       'Mask_mandates_4_Native Hawaiian or Pacific Islander or American Indian or Native American or Alaskan Native or Chamoan or Samoan',
       'Mask_mandates_4_Other or Self-defined or Multi-racial',
       'Mask_mandates_4_White', 'School_closures_2', 
       'School_closures_2_Asian/Asian American or Chinese or Vietnamese or Filipino or Japanese or Asian Indian',
       'School_closures_2_Middle Eastern of North African',
       'School_closures_2_Native Hawaiian or Pacific Islander or American Indian or Native American or Alaskan Native or Chamoan or Samoan',
       'School_closures_2_Other or Self-defined or Multi-racial',
       'School_closures_2_White', 'School_closures_3',
       'School_closures_3_Asian/Asian American or Chinese or Vietnamese or Filipino or Japanese or Asian Indian',
       'School_closures_3_Middle Eastern of North African',
       'School_closures_3_Native Hawaiian or Pacific Islander or American Indian or Native American or Alaskan Native or Chamoan or Samoan',
       'School_closures_3_Other or Self-defined or Multi-racial',
       'School_closures_3_White', 'School_closures_4',
       'School_closures_4_Asian/Asian American or Chinese or Vietnamese or Filipino or Japanese or Asian Indian',
       'School_closures_4_Middle Eastern of North African',
       'School_closures_4_Native Hawaiian or Pacific Islander or American Indian or Native American or Alaskan Native or Chamoan or Samoan',
       'School_closures_4_Other or Self-defined or Multi-racial',
       'School_closures_4_White', 'School_closures_5',
       'School_closures_5_Asian/Asian American or Chinese or Vietnamese or Filipino or Japanese or Asian Indian',
       'School_closures_5_Middle Eastern of North African',
       'School_closures_5_Native Hawaiian or Pacific Islander or American Indian or Native American or Alaskan Native or Chamoan or Samoan',
       'School_closures_5_Other or Self-defined or Multi-racial',
       'School_closures_5_White', 'Transit_2',
       'Transit_2_Asian/Asian American or Chinese or Vietnamese or Filipino or Japanese or Asian Indian',
       'Transit_2_Middle Eastern of North African',
       'Transit_2_Native Hawaiian or Pacific Islander or American Indian or Native American or Alaskan Native or Chamoan or Samoan',
       'Transit_2_Other or Self-defined or Multi-racial', 'Transit_2_White', 
       'Healthcare_restrictions_2',
       'Healthcare_restrictions_2_Asian/Asian American or Chinese or Vietnamese or Filipino or Japanese or Asian Indian',
       'Healthcare_restrictions_2_Middle Eastern of North African',
       'Healthcare_restrictions_2_Native Hawaiian or Pacific Islander or American Indian or Native American or Alaskan Native or Chamoan or Samoan',
       'Healthcare_restrictions_2_Other or Self-defined or Multi-racial',
       'Healthcare_restrictions_2_White', 'Healthcare_restrictions_3',
       'Healthcare_restrictions_3_Asian/Asian American or Chinese or Vietnamese or Filipino or Japanese or Asian Indian',
       'Healthcare_restrictions_3_Middle Eastern of North African',
       'Healthcare_restrictions_3_Native Hawaiian or Pacific Islander or American Indian or Native American or Alaskan Native or Chamoan or Samoan',
       'Healthcare_restrictions_3_Other or Self-defined or Multi-racial',
       'Healthcare_restrictions_3_White',
       'Number_of_infections',
       'Number_of_infections_Asian/Asian American or Chinese or Vietnamese or Filipino or Japanese or Asian Indian',
       'Number_of_infections_Middle Eastern of North African',
       'Number_of_infections_Native Hawaiian or Pacific Islander or American Indian or Native American or Alaskan Native or Chamoan or Samoan',
       'Number_of_infections_Other or Self-defined or Multi-racial',
       'Number_of_infections_White']


reorder_indices_vaccination = ['Business_closures_2', 'Business_closures_2_No',
       'Business_closures_3', 'Business_closures_3_No',
       'Mask_mandates_2', 'Mask_mandates_2_No', 'Mask_mandates_3',
       'Mask_mandates_3_No', 'Mask_mandates_4', 'Mask_mandates_4_No',
       'School_closures_2', 'School_closures_2_No', 'School_closures_3',
       'School_closures_3_No', 'School_closures_4', 'School_closures_4_No',
       'School_closures_5', 'School_closures_5_No', 'Transit_2',
       'Transit_2_No', 'Healthcare_restrictions_2', 'Healthcare_restrictions_2_No',
       'Healthcare_restrictions_3', 'Healthcare_restrictions_3_No',  'Number_of_infections', 'Number_of_infections_No']

# %% [markdown]
# General plot

# %%
results_no_vaccine_filtered = results_no_vaccine.drop(['ACS2', 'SIGMA_PANEL_ASC2'])
results_vaccine_filtered = results_vaccine.drop(['ACS2', 'SIGMA_PANEL_ASC2'])
# Indices and Labels

remove_indices_general = ['Number_of_infections'] # 'Healthcare_restrictions_2', 'Healthcare_restrictions_3'

# Replace values at 'remove_indices' with np.nan

results_no_vaccine_filtered.loc[remove_indices_general, ['WTP_mean', 'WTP_CI_lower', 'WTP_CI_upper']] = np.nan
results_vaccine_filtered.loc[remove_indices_general, ['WTP_mean', 'WTP_CI_lower', 'WTP_CI_upper']] = np.nan

coefficients_no_vaccine = results_no_vaccine_filtered['Value'].loc[reorder_indices]
ci_coefficients_no_vaccine = results_no_vaccine_filtered['Std err'].loc[reorder_indices] * 1.96

coefficients_vaccine = results_vaccine_filtered['Value'].loc[reorder_indices]
ci_coefficients_vaccine = results_vaccine_filtered['Std err'].loc[reorder_indices] * 1.96

# Process WTP data with np.nan values
filtered_wtp_no_vaccine = results_no_vaccine_filtered['WTP_mean'].loc[reorder_indices]
ci_wtp_no_vaccine = [
    filtered_wtp_no_vaccine - results_no_vaccine_filtered['WTP_CI_lower'].loc[reorder_indices],
    results_no_vaccine_filtered['WTP_CI_upper'].loc[reorder_indices] - filtered_wtp_no_vaccine
]

filtered_wtp_vaccine = results_vaccine_filtered['WTP_mean'].loc[reorder_indices]
ci_wtp_vaccine = [
    filtered_wtp_vaccine - results_vaccine_filtered['WTP_CI_lower'].loc[reorder_indices],
    results_vaccine_filtered['WTP_CI_upper'].loc[reorder_indices] - filtered_wtp_vaccine
]

# Plotting setup as before
fig, ax= plt.subplots(1, 2, figsize=FIG_SIZE)
ax1, ax2 = ax
labels = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J'] 

# Plot Coefficients
ax1.errorbar(coefficients_no_vaccine, np.arange(len(coefficients_no_vaccine)),
             xerr=ci_coefficients_no_vaccine, fmt='o', color='#2C5784', ecolor='#1f77b4', capsize=5, alpha=0.7, label='No Vaccine')
if INCLUDE_VACCINE:
    ax1.errorbar(coefficients_vaccine, np.arange(len(coefficients_vaccine)),
                 xerr=ci_coefficients_vaccine, fmt='o', color='#D9534F', ecolor='#ff7f0e', capsize=5, alpha=0.7, label='Vaccine')
ax1.set_xlabel('Coefficient Values', fontsize=14)
ax1.set_yticks(np.arange(len(x_lab_coef)))
ax1.set_yticklabels(x_lab_coef, fontsize=10)

ax1.axvline(x=0, color='black', linestyle='-', linewidth=1.3)
ax1.grid(True, linestyle='--', alpha=0.7)
if INCLUDE_VACCINE:
    ax1.legend()

# Plot WTP
ax2.errorbar(filtered_wtp_no_vaccine, np.arange(len(filtered_wtp_no_vaccine)),
             xerr=ci_wtp_no_vaccine, fmt='o', color='#2C5784', ecolor='#1f77b4', capsize=5, alpha=0.7, label='No Vaccine')
if INCLUDE_VACCINE:
    ax2.errorbar(filtered_wtp_vaccine, np.arange(len(filtered_wtp_vaccine)),
                 xerr=ci_wtp_vaccine, fmt='o', color='#D9534F', ecolor='#ff7f0e', capsize=5, alpha=0.7, label='Vaccine')
ax2.set_xlabel('Willingness to Accept (WTA)', fontsize=14)
ax2.set_yticks(np.arange(len(x_lab_wtp)))
ax2.set_yticklabels(x_lab_wtp, fontsize=10)
ax2.set_yticklabels('', fontsize=10)
ax2.set_ylim(ax1.get_ylim())

ax2.axvline(x=0, color='black', linestyle='-', linewidth=1.3)
ax2.grid(True, linestyle='--', alpha=0.7)
# ax2.legend()

plt.tight_layout(w_pad=3)

plt.savefig('coefficients_WTP_all_both_no_and_with_vaccine_flipped_Reza_presentation.png')
plt.show()

# %% [markdown]
# Gender

# %% [markdown]
# Child

# %%
fig, ax= plt.subplots(1, 2, figsize=FIG_SIZE)

## Gender
x_wtp_gender = []
for i in range(10):  
    x_wtp_gender.extend([i] * 2)
reorder_indices_gender_wtp = [index for index in reorder_indices_gender if not (index.startswith("Healthcare_restrictions") or index.startswith("Number_of_infections"))]

# Filter out rows containing "_Non-binary" or "_Self-define", as bad estimates
filtered_indices = [index for index in results_gender_no_vaccine.index if not (index.endswith('_Non-binary') or index.endswith('_Self-define') or index.endswith('Prefer not to answer'))]
results_gender_no_vaccine = results_gender_no_vaccine.loc[filtered_indices]

filtered_indices = [index for index in results_gender_vaccine.index if not (index.endswith('_Non-binary') or index.endswith('_Self-define') or index.endswith('Prefer not to answer'))]
results_gender_vaccine = results_gender_vaccine.loc[filtered_indices]

remove_indices_no_vaccine = [index for index in results_gender_no_vaccine.index if index.startswith("Healthcare_restrictions") or index.startswith("Number_of_infections")]
remove_indices_vaccine = [index for index in results_gender_vaccine.index if index.startswith("Healthcare_restrictions") or index.startswith("Number_of_infections")]

results_gender_no_vaccine.drop(index=remove_indices_no_vaccine, inplace=True)
results_gender_vaccine.drop(index=remove_indices_vaccine, inplace=True)
# no vaccine
results_gender_no_vaccine_filtered = results_gender_no_vaccine.drop(['ACS2', 'SIGMA_PANEL_ASC2'])
wtp_no_vaccine = results_gender_no_vaccine_filtered['WTP_mean']
p_values_no_vaccine = results_gender_no_vaccine_filtered['p-value']  # Extract p-values

# Apply the reorder to coefficients and confidence intervals
wtp_no_vaccine = wtp_no_vaccine[reorder_indices_gender_wtp]
p_values_no_vaccine = p_values_no_vaccine[reorder_indices_gender_wtp]  # Reorder p-values accordingly

#vaccine
results_gender_vaccine_filtered = results_gender_vaccine.drop(['ACS2', 'SIGMA_PANEL_ASC2'])
wtp_vaccine = results_gender_vaccine_filtered['WTP_mean']
p_values_vaccine = results_gender_vaccine_filtered['p-value']  # Extract p-values

# Apply the reorder to coefficients and confidence intervals
wtp_vaccine = wtp_vaccine[reorder_indices_gender_wtp]
p_values_vaccine = p_values_vaccine[reorder_indices_gender_wtp]  # Reorder p-values accordingly

colors_coef_gender = [

    '#FEB95F' if '_Male' in idx else 
    '#2C5784'  # Default color if none of the conditions match
    for idx in reorder_indices_gender
]

ax[0].errorbar(wtp_no_vaccine, x_wtp_gender, xerr=[results_gender_no_vaccine_filtered['WTP_mean'] - results_gender_no_vaccine_filtered['WTP_CI_lower'], results_gender_no_vaccine_filtered['WTP_CI_upper'] - results_gender_no_vaccine_filtered['WTP_mean']], fmt='none', color='black', ecolor='lightgray', elinewidth=3, capsize=5)
for i in range(len(x_wtp_gender)):
   ax[0].plot(wtp_no_vaccine[i], x_wtp_gender[i],  'o', color=colors_coef_gender[i], markersize=MARKER_SIZE)

# Add "*" for significant p-values
for i, p in enumerate(p_values_no_vaccine):
    if p < 0.05:
        ax[0].text(wtp_no_vaccine[i] + 0.001, x_wtp_gender[i], '*', color='black', fontsize=14, ha='center')

ax[0].set_ylabel('', fontsize=14)
ax[0].set_yticks(np.arange(len(x_lab_single_plots)))
ax[0].set_yticklabels(x_lab_single_plots, rotation=0, ha='right', fontsize=10)
ax[0].grid(True, linestyle='--', alpha=0.7)
ax[0].set_xlim(WTP_X_RANGE)
ax[0].axvline(x=0, color='black', linestyle='-', linewidth=1.3)
ax[0].set_title('Vaccine Not Available')
ax[0].set_xlabel('Willingness to Accept (WTA)')

legend_elements = [
    Line2D([0], [0], marker='o', color='w', label='Male', markerfacecolor='#FEB95F', markersize=MARKER_SIZE),
    Line2D([0], [0], marker='o', color='w', label='Female', markerfacecolor='#2C5784', markersize=MARKER_SIZE), 
]

ax[0].legend(handles=legend_elements, loc='upper left')

# Plot the filtered WTP and their confidence intervals on the second axis
ax[1].errorbar(wtp_vaccine, x_wtp_gender,  xerr=[results_gender_vaccine_filtered['WTP_mean'] - results_gender_vaccine_filtered['WTP_CI_lower'], results_gender_vaccine_filtered['WTP_CI_upper'] - results_gender_vaccine_filtered['WTP_mean']], fmt='none', color='black', ecolor='lightgray', elinewidth=3, capsize=5)
for i in range(len(wtp_vaccine)):
    ax[1].plot(wtp_vaccine[i], x_wtp_gender[i], 'o', color = colors_coef_gender[i], markersize=MARKER_SIZE)
for i, p in enumerate(p_values_vaccine):
    if p < 0.05:
        ax[1].text(wtp_vaccine[i] + 0.001, x_wtp_gender[i],  '*', color='black', fontsize=14, ha='center')

ax[1].set_ylabel('', fontsize=14)
ax[1].set_yticks(np.arange(len(x_lab_single_plots)))
ax[1].set_yticklabels("", rotation=0, ha='right', fontsize=10)
ax[1].grid(True, linestyle='--', alpha=0.7)
ax[1].set_xlim(WTP_X_RANGE)
ax[1].set_title('Vaccine Available')
ax[1].set_xlabel('Willingness to Accept (WTA)')

ax[1].axvline(x=0, color='black', linestyle='-', linewidth=1.3)

plt.tight_layout(w_pad=1.0)

plt.savefig('WTP_gender_both.png')
# Out:
# C:\Users\ry87\AppData\Local\Temp\1\ipykernel_26648\1337440734.py:48: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ax[0].plot(wtp_no_vaccine[i], x_wtp_gender[i],  'o', color=colors_coef_gender[i], markersize=MARKER_SIZE)
# C:\Users\ry87\AppData\Local\Temp\1\ipykernel_26648\1337440734.py:53: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ax[0].text(wtp_no_vaccine[i] + 0.001, x_wtp_gender[i], '*', color='black', fontsize=14, ha='center')
# ...

# %% [markdown]
# Race

# %%
fig, ax= plt.subplots(1, 2, figsize=FIG_SIZE)

## Gender
x_wtp_gender = []
for i in range(10):  
    x_wtp_gender.extend([i] * 2)
reorder_indices_gender_wtp = [index for index in reorder_indices_gender if not (index.startswith("Healthcare_restrictions") or index.startswith("Number_of_infections"))]

# Filter out rows containing "_Non-binary" or "_Self-define", as bad estimates
filtered_indices = [index for index in results_gender_no_vaccine.index if not (index.endswith('_Non-binary') or index.endswith('_Self-define') or index.endswith('Prefer not to answer'))]
results_gender_no_vaccine = results_gender_no_vaccine.loc[filtered_indices]

filtered_indices = [index for index in results_gender_vaccine.index if not (index.endswith('_Non-binary') or index.endswith('_Self-define') or index.endswith('Prefer not to answer'))]
results_gender_vaccine = results_gender_vaccine.loc[filtered_indices]

remove_indices_no_vaccine = [index for index in results_gender_no_vaccine.index if index.startswith("Healthcare_restrictions") or index.startswith("Number_of_infections")]
remove_indices_vaccine = [index for index in results_gender_vaccine.index if index.startswith("Healthcare_restrictions") or index.startswith("Number_of_infections")]

results_gender_no_vaccine.drop(index=remove_indices_no_vaccine, inplace=True)
results_gender_vaccine.drop(index=remove_indices_vaccine, inplace=True)
# no vaccine
results_gender_no_vaccine_filtered = results_gender_no_vaccine.drop(['ACS2', 'SIGMA_PANEL_ASC2'])
wtp_no_vaccine = results_gender_no_vaccine_filtered['WTP_mean']
p_values_no_vaccine = results_gender_no_vaccine_filtered['p-value']  # Extract p-values

# Apply the reorder to coefficients and confidence intervals
wtp_no_vaccine = wtp_no_vaccine[reorder_indices_gender_wtp]
p_values_no_vaccine = p_values_no_vaccine[reorder_indices_gender_wtp]  # Reorder p-values accordingly

#vaccine
results_gender_vaccine_filtered = results_gender_vaccine.drop(['ACS2', 'SIGMA_PANEL_ASC2'])
wtp_vaccine = results_gender_vaccine_filtered['WTP_mean']
p_values_vaccine = results_gender_vaccine_filtered['p-value']  # Extract p-values

# Apply the reorder to coefficients and confidence intervals
wtp_vaccine = wtp_vaccine[reorder_indices_gender_wtp]
p_values_vaccine = p_values_vaccine[reorder_indices_gender_wtp]  # Reorder p-values accordingly

colors_coef = [

    '#FEB95F' if '_Male' in idx else 
    '#2C5784'  # Default color if none of the conditions match
    for idx in reorder_indices_gender
]

ax[0].errorbar(wtp_no_vaccine, x_wtp_gender, xerr=[results_gender_no_vaccine_filtered['WTP_mean'] - results_gender_no_vaccine_filtered['WTP_CI_lower'], results_gender_no_vaccine_filtered['WTP_CI_upper'] - results_gender_no_vaccine_filtered['WTP_mean']], fmt='none', color='black', ecolor='lightgray', elinewidth=3, capsize=5)
for i in range(len(x_wtp_gender)):
   ax[0].plot(wtp_no_vaccine[i], x_wtp_gender[i],  'o', color=colors_coef[i], markersize=MARKER_SIZE)

# Add "*" for significant p-values
for i, p in enumerate(p_values_no_vaccine):
    if p < 0.05:
        ax[0].text(wtp_no_vaccine[i] + 0.001, x_wtp_gender[i], '*', color='black', fontsize=14, ha='center')

ax[0].set_ylabel('', fontsize=14)
ax[0].set_yticks(np.arange(len(x_lab_single_plots)))
ax[0].set_yticklabels(x_lab_single_plots, rotation=0, ha='right', fontsize=10)
ax[0].grid(True, linestyle='--', alpha=0.7)
ax[0].set_xlim(WTP_X_RANGE)
ax[0].axvline(x=0, color='black', linestyle='-', linewidth=1.3)
ax[0].set_title('Vaccine Not Available')
ax[0].set_xlabel('Willingness to Accept (WTA)')

legend_elements = [
    Line2D([0], [0], marker='o', color='w', label='Male', markerfacecolor='#FEB95F', markersize=MARKER_SIZE),
    Line2D([0], [0], marker='o', color='w', label='Female', markerfacecolor='#2C5784', markersize=MARKER_SIZE), 
]

ax[0].legend(handles=legend_elements, loc='upper left', fontsize=8)

# Plot the filtered WTP and their confidence intervals on the second axis
ax[1].errorbar(wtp_vaccine, x_wtp_gender,  xerr=[results_gender_vaccine_filtered['WTP_mean'] - results_gender_vaccine_filtered['WTP_CI_lower'], results_gender_vaccine_filtered['WTP_CI_upper'] - results_gender_vaccine_filtered['WTP_mean']], fmt='none', color='black', ecolor='lightgray', elinewidth=3, capsize=5)
for i in range(len(wtp_vaccine)):
    ax[1].plot(wtp_vaccine[i], x_wtp_gender[i], 'o', color = colors_coef[i], markersize=MARKER_SIZE)
for i, p in enumerate(p_values_vaccine):
    if p < 0.05:
        ax[1].text(wtp_vaccine[i] + 0.001, x_wtp_gender[i],  '*', color='black', fontsize=14, ha='center')

ax[1].set_ylabel('', fontsize=14)
ax[1].set_yticks(np.arange(len(x_lab_single_plots)))
ax[1].set_yticklabels("", rotation=0, ha='right', fontsize=10)
ax[1].grid(True, linestyle='--', alpha=0.7)
ax[1].set_xlim(WTP_X_RANGE)
ax[1].set_title('Vaccine Available')
ax[1].set_xlabel('Willingness to Accept (WTA)')

ax[1].axvline(x=0, color='black', linestyle='-', linewidth=1.3)

plt.tight_layout(w_pad=1.0)

plt.savefig('WTP_gender_both.png')
# Out:
# C:\Users\ry87\AppData\Local\Temp\1\ipykernel_26648\526600175.py:48: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ax[0].plot(wtp_no_vaccine[i], x_wtp_gender[i],  'o', color=colors_coef[i], markersize=MARKER_SIZE)
# C:\Users\ry87\AppData\Local\Temp\1\ipykernel_26648\526600175.py:53: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ax[0].text(wtp_no_vaccine[i] + 0.001, x_wtp_gender[i], '*', color='black', fontsize=14, ha='center')
# ...

# %%
fig, ax = plt.subplots(1, 2, figsize=FIG_SIZE)

## Race
x_wtp_race = []
for i in range(10):  
    x_wtp_race.extend([i] * 6)
reorder_indices_race_wtp = [index for index in reorder_indices_race if not (index.startswith("Healthcare_restrictions") or index.startswith("Number_of_infections"))]

remove_indices_no_vaccine = [index for index in results_race_no_vaccine.index if index.startswith("Healthcare_restrictions") or index.startswith("Number_of_infections")]
remove_indices_vaccine = [index for index in results_race_vaccine.index if index.startswith("Healthcare_restrictions") or index.startswith("Number_of_infections")]

results_race_no_vaccine.drop(index=remove_indices_no_vaccine, inplace=True)
results_race_vaccine.drop(index=remove_indices_vaccine, inplace=True)
# no vaccine
results_race_no_vaccine_filtered = results_race_no_vaccine.drop(['ACS2', 'SIGMA_PANEL_ASC2'])
wtp_no_vaccine = results_race_no_vaccine_filtered['WTP_mean']
p_values_no_vaccine = results_race_no_vaccine_filtered['p-value']  # Extract p-values

# Apply the reorder to coefficients and confidence intervals
wtp_no_vaccine = wtp_no_vaccine[reorder_indices_race_wtp]
p_values_no_vaccine = p_values_no_vaccine[reorder_indices_race_wtp]  # Reorder p-values accordingly

# vaccine
results_race_vaccine_filtered = results_race_vaccine.drop(['ACS2', 'SIGMA_PANEL_ASC2'])
wtp_vaccine = results_race_vaccine_filtered['WTP_mean']
p_values_vaccine = results_race_vaccine_filtered['p-value']  # Extract p-values

# Apply the reorder to coefficients and confidence intervals
wtp_vaccine = wtp_vaccine[reorder_indices_race_wtp]
p_values_vaccine = p_values_vaccine[reorder_indices_race_wtp]  # Reorder p-values accordingly

colors_coef_race = [
    '#2ca02c' if '_Native Hawaiian or Pacific Islander or American Indian or Native American or Alaskan Native or Chamoan or Samoan' in idx else 
    '#1f77b4' if '_Asian/Asian American or Chinese or Vietnamese or Filipino or Japanese or Asian Indian' in idx else 
    '#ff7f0e' if '_Middle Eastern of North African' in idx else 
    '#d62728' if '_Other or Self-defined or Multi-racial' in idx else 
    '#9467bd' if '_White' in idx else 
    '#8c564b'  # Default color if none of the conditions match (Brown)
    for idx in reorder_indices_race
]


ax[0].errorbar(wtp_no_vaccine, x_wtp_race, xerr=[results_race_no_vaccine_filtered['WTP_mean'] - results_race_no_vaccine_filtered['WTP_CI_lower'], results_race_no_vaccine_filtered['WTP_CI_upper'] - results_race_no_vaccine_filtered['WTP_mean']], fmt='none', color='black', ecolor='lightgray', elinewidth=3, capsize=5)
for i in range(len(x_wtp_race)):
    ax[0].plot(wtp_no_vaccine[i], x_wtp_race[i], 'o', color=colors_coef_race[i], markersize=MARKER_SIZE)

# Add "*" for significant p-values
for i, p in enumerate(p_values_no_vaccine):
    if p < 0.05:
        ax[0].text(wtp_no_vaccine[i] + 0.001, x_wtp_race[i], '*', color='black', fontsize=14, ha='center')

ax[0].set_ylabel('', fontsize=14)
ax[0].set_yticks(np.arange(len(x_lab_single_plots)))
ax[0].set_yticklabels(x_lab_single_plots, rotation=0, ha='right', fontsize=10)
ax[0].grid(True, linestyle='--', alpha=0.7)
ax[0].set_xlim(-900, 900)
ax[0].axvline(x=0, color='black', linestyle='-', linewidth=1.3)
ax[0].set_title('Vaccine Not Available')
ax[0].set_xlabel('Willingness to Accept (WTA)')

legend_elements_race = [
    Line2D([0], [0], marker='o', color='w', label='African American/\nBlack', markerfacecolor='#8c564b', markersize=MARKER_SIZE),
    Line2D([0], [0], marker='o', color='w', label='Asian/Asian American\nor Chinese or Vietnamese\nor Filipino or Japanese\nor Asian Indian', markerfacecolor='#1f77b4', markersize=MARKER_SIZE),
    Line2D([0], [0], marker='o', color='w', label='Middle Eastern\nor North African', markerfacecolor='#ff7f0e', markersize=MARKER_SIZE),
    Line2D([0], [0], marker='o', color='w', label='Native Hawaiian\nor Pacific Islander\nor American Indian\nor Native American\nor Alaskan Native\nor Chamoan or Samoan', markerfacecolor='#2ca02c', markersize=MARKER_SIZE),
    Line2D([0], [0], marker='o', color='w', label='Other or Self-defined\nor Multi-racial', markerfacecolor='#d62728', markersize=MARKER_SIZE),
    Line2D([0], [0], marker='o', color='w', label='White', markerfacecolor='#9467bd', markersize=10)
]


ax[0].legend(handles=legend_elements_race, loc='best')

# Plot the filtered WTP and their confidence intervals on the second axis
ax[1].errorbar(wtp_vaccine, x_wtp_race, xerr=[results_race_vaccine_filtered['WTP_mean'] - results_race_vaccine_filtered['WTP_CI_lower'], results_race_vaccine_filtered['WTP_CI_upper'] - results_race_vaccine_filtered['WTP_mean']], fmt='none', color='black', ecolor='lightgray', elinewidth=3, capsize=5)
for i in range(len(wtp_vaccine)):
    ax[1].plot(wtp_vaccine[i], x_wtp_race[i], 'o', color=colors_coef_race[i], markersize=MARKER_SIZE)
for i, p in enumerate(p_values_vaccine):
    if p < 0.05:
        ax[1].text(wtp_vaccine[i] + 0.001, x_wtp_race[i], '*', color='black', fontsize=14, ha='center')

ax[1].set_ylabel('', fontsize=14)
ax[1].set_yticks(np.arange(len(x_lab_single_plots)))
ax[1].set_yticklabels("", rotation=0, ha='right', fontsize=10)
ax[1].grid(True, linestyle='--', alpha=0.7)
ax[1].axvline(x=0, color='black', linestyle='-', linewidth=1.3)
ax[1].set_xlim(-900, 900)
ax[1].set_title('Vaccine Available')
ax[1].set_xlabel('Willingness to Accept (WTA)')

plt.tight_layout(w_pad=3.0)
plt.savefig('WTP_race_both.png')
# Out:
# C:\Users\ry87\AppData\Local\Temp\1\ipykernel_26648\2659446913.py:45: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ax[0].plot(wtp_no_vaccine[i], x_wtp_race[i], 'o', color=colors_coef_race[i], markersize=MARKER_SIZE)
# C:\Users\ry87\AppData\Local\Temp\1\ipykernel_26648\2659446913.py:50: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ax[0].text(wtp_no_vaccine[i] + 0.001, x_wtp_race[i], '*', color='black', fontsize=14, ha='center')
# ...

# %% [markdown]
# Age

# %%
fig, ax = plt.subplots(1, 2, figsize=FIG_SIZE)

x_wtp_age = []
for i in range(10):  
    x_wtp_age.extend([i] * 5) 
reorder_indices_age_wtp = [index for index in reorder_indices_age if not (index.startswith("Healthcare_restrictions") or index.startswith("Number_of_infections"))]

remove_indices_no_vaccine = [index for index in results_age_no_vaccine.index if index.startswith("Healthcare_restrictions") or index.startswith("Number_of_infections")]
remove_indices_vaccine = [index for index in results_age_vaccine.index if index.startswith("Healthcare_restrictions") or index.startswith("Number_of_infections")]

results_age_no_vaccine.drop(index=remove_indices_no_vaccine, inplace=True)
results_age_vaccine.drop(index=remove_indices_vaccine, inplace=True)
# no vaccine
results_age_no_vaccine_filtered = results_age_no_vaccine.drop(['ACS2', 'SIGMA_PANEL_ASC2'])
wtp_no_vaccine = results_age_no_vaccine_filtered['WTP_mean']
p_values_no_vaccine = results_age_no_vaccine_filtered['p-value']  # Extract p-values

# Apply the reorder to coefficients and confidence intervals
wtp_no_vaccine = wtp_no_vaccine[reorder_indices_age_wtp]
p_values_no_vaccine = p_values_no_vaccine[reorder_indices_age_wtp]  # Reorder p-values accordingly

# vaccine
results_age_vaccine_filtered = results_age_vaccine.drop(['ACS2', 'SIGMA_PANEL_ASC2'])
wtp_vaccine = results_age_vaccine_filtered['WTP_mean']
p_values_vaccine = results_age_vaccine_filtered['p-value']  # Extract p-values

# Apply the reorder to coefficients and confidence intervals
wtp_vaccine = wtp_vaccine[reorder_indices_age_wtp]
p_values_vaccine = p_values_vaccine[reorder_indices_age_wtp]  # Reorder p-values accordingly

legend_elements_age = [
    Line2D([0], [0], marker='o', color='w', label='≥ 65', markerfacecolor='#F71735', markersize=MARKER_SIZE),
    Line2D([0], [0], marker='o', color='w', label='50-64', markerfacecolor='#9A348E', markersize=MARKER_SIZE),
    Line2D([0], [0], marker='o', color='w', label='35-49', markerfacecolor='#FEB95F', markersize=MARKER_SIZE),
    Line2D([0], [0], marker='o', color='w', label='25-34', markerfacecolor='#00A676', markersize=MARKER_SIZE),
    Line2D([0], [0], marker='o', color='w', label='18-24', markerfacecolor='#2C5784', markersize=MARKER_SIZE)
]

colors_coef_age = [
    '#F71735' if '_≥ 65' in idx else 
    '#9A348E' if '_50-64' in idx else 
    '#FEB95F' if '_35-49' in idx else 
    '#00A676' if '_25-34' in idx else 

    '#2C5784'  # Default color if none of the conditions match
    for idx in reorder_indices_age_wtp
]


ax[0].errorbar(wtp_no_vaccine, x_wtp_age, xerr=[results_age_no_vaccine_filtered['WTP_mean'] - results_age_no_vaccine_filtered['WTP_CI_lower'], results_age_no_vaccine_filtered['WTP_CI_upper'] - results_age_no_vaccine_filtered['WTP_mean']], fmt='none', color='black', ecolor='lightgray', elinewidth=3, capsize=5)
for i in range(len(x_wtp_age)):
    ax[0].plot(wtp_no_vaccine[i], x_wtp_age[i], 'o', color=colors_coef_age[i], markersize=MARKER_SIZE)

# Add "*" for significant p-values
for i, p in enumerate(p_values_no_vaccine):
    if p < 0.05:
        ax[0].text(wtp_no_vaccine[i] + 0.001, x_wtp_age[i], '*', color='black', fontsize=14, ha='center')

ax[0].set_ylabel('', fontsize=14)
ax[0].set_yticks(np.arange(len(x_lab_single_plots)))
ax[0].set_yticklabels(x_lab_single_plots, rotation=0, ha='right', fontsize=10)
ax[0].grid(True, linestyle='--', alpha=0.7)
ax[0].set_xlim(WTP_X_RANGE)
ax[0].axvline(x=0, color='black', linestyle='-', linewidth=1.3)
ax[0].set_title('Vaccine Not Available')
ax[0].set_xlabel('Willingness to Accept (WTA)')

# Create legend elements for the 4 age categories
legend_elements_age = [
    Line2D([0], [0], marker='o', color='w', label='18-24', markerfacecolor='#1f77b4', markersize=MARKER_SIZE),
    Line2D([0], [0], marker='o', color='w', label='25-34', markerfacecolor='#ff7f0e', markersize=MARKER_SIZE),
    Line2D([0], [0], marker='o', color='w', label='35-44', markerfacecolor='#2ca02c', markersize=MARKER_SIZE),
    Line2D([0], [0], marker='o', color='w', label='45+', markerfacecolor='#d62728', markersize=MARKER_SIZE)
]

ax[0].legend(handles=legend_elements_age, loc='best')

# Plot the filtered WTP and their confidence intervals on the second axis
ax[1].errorbar(wtp_vaccine, x_wtp_age, xerr=[results_age_vaccine_filtered['WTP_mean'] - results_age_vaccine_filtered['WTP_CI_lower'], results_age_vaccine_filtered['WTP_CI_upper'] - results_age_vaccine_filtered['WTP_mean']], fmt='none', color='black', ecolor='lightgray', elinewidth=3, capsize=5)
for i in range(len(wtp_vaccine)):
    ax[1].plot(wtp_vaccine[i], x_wtp_age[i], 'o', color=colors_coef_age[i], markersize=MARKER_SIZE)
for i, p in enumerate(p_values_vaccine):
    if p < 0.05:
        ax[1].text(wtp_vaccine[i] + 0.001, x_wtp_age[i], '*', color='black', fontsize=14, ha='center')

ax[1].set_ylabel('', fontsize=14)
ax[1].set_yticks(np.arange(len(x_lab_single_plots)))
ax[1].set_yticklabels("", rotation=0, ha='right', fontsize=10)
ax[1].grid(True, linestyle='--', alpha=0.7)
ax[1].axvline(x=0, color='black', linestyle='-', linewidth=1.3)
ax[1].set_xlim(WTP_X_RANGE)
ax[1].set_title('Vaccine Available')
ax[1].set_xlabel('Willingness to Accept (WTA)')

plt.tight_layout(w_pad=1.0)
plt.savefig('WTP_age_both.png')
# Out:
# C:\Users\ry87\AppData\Local\Temp\1\ipykernel_26648\1449257182.py:52: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ax[0].plot(wtp_no_vaccine[i], x_wtp_age[i], 'o', color=colors_coef_age[i], markersize=MARKER_SIZE)
# C:\Users\ry87\AppData\Local\Temp\1\ipykernel_26648\1449257182.py:57: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ax[0].text(wtp_no_vaccine[i] + 0.001, x_wtp_age[i], '*', color='black', fontsize=14, ha='center')
# ...

# %% [markdown]
# Chronic

# %%
fig, ax = plt.subplots(1, 2, figsize=FIG_SIZE)

x_wtp_chronic = []
for i in range(10):  
    x_wtp_chronic.extend([i] * 3) 
reorder_indices_chronic_wtp = [index for index in reorder_indices_chronic if not (index.startswith("Healthcare_restrictions") or index.startswith("Number_of_infections"))]

remove_indices_no_vaccine = [index for index in results_chronic_no_vaccine.index if index.startswith("Healthcare_restrictions") or index.startswith("Number_of_infections")
                             ]
remove_indices_vaccine = [index for index in results_chronic_vaccine.index if index.startswith("Healthcare_restrictions") or index.startswith("Number_of_infections")
                          ]

results_chronic_no_vaccine.drop(index=remove_indices_no_vaccine, inplace=True)
results_chronic_vaccine.drop(index=remove_indices_vaccine, inplace=True)

# no vaccine
results_chronic_no_vaccine_filtered = results_chronic_no_vaccine.drop(['ACS2', 'SIGMA_PANEL_ASC2'])
wtp_no_vaccine = results_chronic_no_vaccine_filtered['WTP_mean']
p_values_no_vaccine = results_chronic_no_vaccine_filtered['p-value']  # Extract p-values

# Apply the reorder to coefficients and confidence intervals
wtp_no_vaccine = wtp_no_vaccine[reorder_indices_chronic_wtp]
p_values_no_vaccine = p_values_no_vaccine[reorder_indices_chronic_wtp]  # Reorder p-values accordingly

# vaccine
results_chronic_vaccine_filtered = results_chronic_vaccine.drop(['ACS2', 'SIGMA_PANEL_ASC2'])
wtp_vaccine = results_chronic_vaccine_filtered['WTP_mean']
p_values_vaccine = results_chronic_vaccine_filtered['p-value']  # Extract p-values

# Apply the reorder to coefficients and confidence intervals
wtp_vaccine = wtp_vaccine[reorder_indices_chronic_wtp]
p_values_vaccine = p_values_vaccine[reorder_indices_chronic_wtp]  # Reorder p-values accordingly

colors_coef_chronic = [
    'green' if '_No' in idx else 
    'grey' if '_Prefer not to answer' in idx else 
    'red'  # Default color if none of the conditions match
    for idx in reorder_indices_chronic
]

legend_elements_chronic = [
    Line2D([0], [0], marker='o', color='w', label='No', markerfacecolor='green', markersize=MARKER_SIZE),
    Line2D([0], [0], marker='o', color='w', label='Yes', markerfacecolor='red', markersize=MARKER_SIZE),
    Line2D([0], [0], marker='o', color='w', label='Prefer N/A', markerfacecolor='grey', markersize=MARKER_SIZE)
]
ax[0].errorbar(wtp_no_vaccine, x_wtp_chronic, xerr=[results_chronic_no_vaccine_filtered['WTP_mean'] - results_chronic_no_vaccine_filtered['WTP_CI_lower'], results_chronic_no_vaccine_filtered['WTP_CI_upper'] - results_chronic_no_vaccine_filtered['WTP_mean']], fmt='none', color='black', ecolor='lightgray', elinewidth=3, capsize=5)
for i in range(len(x_wtp_chronic)):
    ax[0].plot(wtp_no_vaccine[i], x_wtp_chronic[i], 'o', color=colors_coef_chronic[i], markersize=MARKER_SIZE)

# Add "*" for significant p-values
for i, p in enumerate(p_values_no_vaccine):
    if p < 0.05 and wtp_no_vaccine[i] + 0.001 < 200:
        ax[0].text(wtp_no_vaccine[i] + 0.001, x_wtp_chronic[i], '*', color='black', fontsize=14, ha='center')

ax[0].set_ylabel('', fontsize=14)
ax[0].set_yticks(np.arange(len(x_lab_single_plots)))
ax[0].set_yticklabels(x_lab_single_plots, rotation=0, ha='right', fontsize=10)
ax[0].grid(True, linestyle='--', alpha=0.7)
ax[0].set_xlim(WTP_X_RANGE)
ax[0].axvline(x=0, color='black', linestyle='-', linewidth=1.3)
ax[0].set_title('Vaccine Not Available')
ax[0].set_xlabel('Willingness to Accept (WTA)')

# Add chronic condition legend
ax[0].legend(handles=legend_elements_chronic, loc='upper left', fontsize=8)

# Plot the filtered WTP and their confidence intervals on the second axis
ax[1].errorbar(wtp_vaccine, x_wtp_chronic, xerr=[results_chronic_vaccine_filtered['WTP_mean'] - results_chronic_vaccine_filtered['WTP_CI_lower'], results_chronic_vaccine_filtered['WTP_CI_upper'] - results_chronic_vaccine_filtered['WTP_mean']], fmt='none', color='black', ecolor='lightgray', elinewidth=3, capsize=5)
for i in range(len(wtp_vaccine)):
    ax[1].plot(wtp_vaccine[i], x_wtp_chronic[i], 'o', color=colors_coef_chronic[i], markersize=MARKER_SIZE)
for i, p in enumerate(p_values_vaccine):
    if p < 0.05:
        ax[1].text(wtp_vaccine[i] + 0.001, x_wtp_chronic[i], '*', color='black', fontsize=14, ha='center')

ax[1].set_ylabel('', fontsize=14)
ax[1].set_yticks(np.arange(len(x_lab_single_plots)))
ax[1].set_yticklabels("", rotation=0, ha='right', fontsize=10)
# ax[0].set_xlim(-450, 450)

ax[1].grid(True, linestyle='--', alpha=0.7)
ax[1].axvline(x=0, color='black', linestyle='-', linewidth=1.3)
ax[1].set_xlim(WTP_X_RANGE)
ax[1].set_title('Vaccine Available')
ax[1].set_xlabel('Willingness to Accept (WTA)')

plt.tight_layout(w_pad=1.0)

plt.savefig('WTP_chronic_both.png')
# Out:
# C:\Users\ry87\AppData\Local\Temp\1\ipykernel_26648\4132211294.py:48: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ax[0].plot(wtp_no_vaccine[i], x_wtp_chronic[i], 'o', color=colors_coef_chronic[i], markersize=MARKER_SIZE)
# C:\Users\ry87\AppData\Local\Temp\1\ipykernel_26648\4132211294.py:52: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if p < 0.05 and wtp_no_vaccine[i] + 0.001 < 200:
# ...

# %% [markdown]
# Political

# %%
fig, ax = plt.subplots(1, 2, figsize=FIG_SIZE)

x_wtp_political = []
for i in range(10):  
    x_wtp_political.extend([i] * 4) 
    
reorder_indices_political_wtp = [index for index in reorder_indices_political if not (index.startswith("Healthcare_restrictions") or index.startswith("Number_of_infections"))]

remove_indices_no_vaccine = [index for index in results_political_no_vaccine.index if index.startswith("Healthcare_restrictions") or index.startswith("Number_of_infections")]
remove_indices_vaccine = [index for index in results_political_vaccine.index if index.startswith("Healthcare_restrictions") or index.startswith("Number_of_infections")]

results_political_no_vaccine.drop(index=remove_indices_no_vaccine, inplace=True)
results_political_vaccine.drop(index=remove_indices_vaccine, inplace=True)

# no vaccine
results_political_no_vaccine_filtered = results_political_no_vaccine.drop(['ACS2', 'SIGMA_PANEL_ASC2'])
wtp_no_vaccine = results_political_no_vaccine_filtered['WTP_mean']
p_values_no_vaccine = results_political_no_vaccine_filtered['p-value']  # Extract p-values

# Apply the reorder to coefficients and confidence intervals
wtp_no_vaccine = wtp_no_vaccine[reorder_indices_political_wtp]
p_values_no_vaccine = p_values_no_vaccine[reorder_indices_political_wtp]  # Reorder p-values accordingly

# vaccine
results_political_vaccine_filtered = results_political_vaccine.drop(['ACS2', 'SIGMA_PANEL_ASC2'])
wtp_vaccine = results_political_vaccine_filtered['WTP_mean']
p_values_vaccine = results_political_vaccine_filtered['p-value']  # Extract p-values

# Apply the reorder to coefficients and confidence intervals
wtp_vaccine = wtp_vaccine[reorder_indices_political_wtp]
p_values_vaccine = p_values_vaccine[reorder_indices_political_wtp]  # Reorder p-values accordingly
# Define colors for the different political groups
colors_coef_political = [
    '#F71735' if '_Republican' in idx else 
    '#FEB95F' if '_Independent' in idx else 
    '#00A676' if '_Other' in idx else 
    '#005f73' if '_Democrat' in idx else  # Default color if none of the conditions match
    '#005f73'  # Default color
    for idx in reorder_indices_political
]

legend_elements_political = [
    Line2D([0], [0], marker='o', color='w', label='Republican', markerfacecolor='#F71735', markersize=MARKER_SIZE),
    Line2D([0], [0], marker='o', color='w', label='Independent', markerfacecolor='#FEB95F', markersize=MARKER_SIZE),
    Line2D([0], [0], marker='o', color='w', label='Other', markerfacecolor='#00A676', markersize=MARKER_SIZE),
    Line2D([0], [0], marker='o', color='w', label='Democrat', markerfacecolor='#2C5784', markersize=MARKER_SIZE)
]


ax[0].errorbar(wtp_no_vaccine, x_wtp_political, xerr=[results_political_no_vaccine_filtered['WTP_mean'] - results_political_no_vaccine_filtered['WTP_CI_lower'], results_political_no_vaccine_filtered['WTP_CI_upper'] - results_political_no_vaccine_filtered['WTP_mean']], fmt='none', color='black', ecolor='lightgray', elinewidth=3, capsize=5)
for i in range(len(x_wtp_political)):
    ax[0].plot(wtp_no_vaccine[i], x_wtp_political[i], 'o', color=colors_coef_political[i], markersize=MARKER_SIZE)

# Add "*" for significant p-values
for i, p in enumerate(p_values_no_vaccine):
    if p < 0.05:
        ax[0].text(wtp_no_vaccine[i] + 0.001, x_wtp_political[i], '*', color='black', fontsize=14, ha='center')

ax[0].set_ylabel('', fontsize=14)
ax[0].set_yticks(np.arange(len(x_lab_single_plots)))
ax[0].set_yticklabels(x_lab_single_plots, rotation=0, ha='right', fontsize=10)
ax[0].grid(True, linestyle='--', alpha=0.7)
ax[0].set_xlim(WTP_X_RANGE)
ax[0].axvline(x=0, color='black', linestyle='-', linewidth=1.3)
ax[0].set_title('Vaccine Not Available')
ax[0].set_xlabel('Willingness to Accept (WTA)')

# Add political condition legend
ax[0].legend(handles=legend_elements_political, loc='upper left', fontsize=8)

# Plot the filtered WTP and their confidence intervals on the second axis
ax[1].errorbar(wtp_vaccine, x_wtp_political, xerr=[results_political_vaccine_filtered['WTP_mean'] - results_political_vaccine_filtered['WTP_CI_lower'], results_political_vaccine_filtered['WTP_CI_upper'] - results_political_vaccine_filtered['WTP_mean']], fmt='none', color='black', ecolor='lightgray', elinewidth=3, capsize=5)
for i in range(len(wtp_vaccine)):
    ax[1].plot(wtp_vaccine[i], x_wtp_political[i], 'o', color=colors_coef_political[i], markersize=MARKER_SIZE)
for i, p in enumerate(p_values_vaccine):
    if p < 0.05:
        ax[1].text(wtp_vaccine[i] + 0.001, x_wtp_political[i], '*', color='black', fontsize=14, ha='center')

ax[1].set_ylabel('', fontsize=14)
ax[1].set_yticks(np.arange(len(x_lab_single_plots)))
ax[1].set_yticklabels("", rotation=0, ha='right', fontsize=10)
ax[1].grid(True, linestyle='--', alpha=0.7)
ax[1].axvline(x=0, color='black', linestyle='-', linewidth=1.3)
ax[1].set_xlim(WTP_X_RANGE)
ax[1].set_title('Vaccine Available')
ax[1].set_xlabel('Willingness to Accept (WTA)')

plt.tight_layout(w_pad=1.0)
plt.savefig('WTP_politics_both.png')
# Out:
# C:\Users\ry87\AppData\Local\Temp\1\ipykernel_26648\1635078412.py:52: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ax[0].plot(wtp_no_vaccine[i], x_wtp_political[i], 'o', color=colors_coef_political[i], markersize=MARKER_SIZE)
# C:\Users\ry87\AppData\Local\Temp\1\ipykernel_26648\1635078412.py:57: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ax[0].text(wtp_no_vaccine[i] + 0.001, x_wtp_political[i], '*', color='black', fontsize=14, ha='center')
# ...

# %% [markdown]
# Vaccination

# %%
fig, ax = plt.subplots(1, 2, figsize=FIG_SIZE)


x_wtp_vaccination = []
for i in range(10):  
    x_wtp_vaccination.extend([i] * 2) 
reorder_indices_vaccination_wtp = [index for index in reorder_indices_vaccination if not (index.startswith("Healthcare_restrictions") or index.startswith("Number_of_infections"))]

remove_indices_no_vaccine = [index for index in results_vaccination_no_vaccine.index if index.startswith("Healthcare_restrictions") or index.startswith("Number_of_infections")]
remove_indices_vaccine = [index for index in results_vaccination_vaccine.index if index.startswith("Healthcare_restrictions") or index.startswith("Number_of_infections")]

results_vaccination_no_vaccine.drop(index=remove_indices_no_vaccine, inplace=True)
results_vaccination_vaccine.drop(index=remove_indices_vaccine, inplace=True)

# no vaccine
results_vaccination_no_vaccine_filtered = results_vaccination_no_vaccine.drop(['ACS2', 'SIGMA_PANEL_ASC2'])
wtp_no_vaccine = results_vaccination_no_vaccine_filtered['WTP_mean']
p_values_no_vaccine = results_vaccination_no_vaccine_filtered['p-value']  # Extract p-values

# Apply the reorder to coefficients and confidence intervals
wtp_no_vaccine = wtp_no_vaccine[reorder_indices_vaccination_wtp]
p_values_no_vaccine = p_values_no_vaccine[reorder_indices_vaccination_wtp]  # Reorder p-values accordingly

# vaccine
results_vaccination_vaccine_filtered = results_vaccination_vaccine.drop(['ACS2', 'SIGMA_PANEL_ASC2'])
wtp_vaccine = results_vaccination_vaccine_filtered['WTP_mean']
p_values_vaccine = results_vaccination_vaccine_filtered['p-value']  # Extract p-values

# Apply the reorder to coefficients and confidence intervals
wtp_vaccine = wtp_vaccine[reorder_indices_vaccination_wtp]
p_values_vaccine = p_values_vaccine[reorder_indices_vaccination_wtp]  # Reorder p-values accordingly

# Define vaccination condition categories and colors
legend_elements_vaccination = [
    Line2D([0], [0], marker='o', color='w', label='Not Vaccinated', markerfacecolor='#F71735', markersize=MARKER_SIZE),
    Line2D([0], [0], marker='o', color='w', label='Vaccinated', markerfacecolor='#FEB95F', markersize=MARKER_SIZE)
]

colors_coef_vaccination = [
    '#F71735' if '_No' in idx else 
    '#FEB95F'  # Default color for Full Vaccination
    for idx in reorder_indices_vaccination_wtp
]

ax[0].errorbar(wtp_no_vaccine, x_wtp_vaccination, xerr=[results_vaccination_no_vaccine_filtered['WTP_mean'] - results_vaccination_no_vaccine_filtered['WTP_CI_lower'], results_vaccination_no_vaccine_filtered['WTP_CI_upper'] - results_vaccination_no_vaccine_filtered['WTP_mean']], fmt='none', color='black', ecolor='lightgray', elinewidth=3, capsize=5)
for i in range(len(x_wtp_vaccination)):
    ax[0].plot(wtp_no_vaccine[i], x_wtp_vaccination[i], 'o', color=colors_coef_vaccination[i], markersize=MARKER_SIZE)

# Add "*" for significant p-values
for i, p in enumerate(p_values_no_vaccine):
    if p < 0.05:
        ax[0].text(wtp_no_vaccine[i] + 0.001, x_wtp_vaccination[i], '*', color='black', fontsize=14, ha='center')

ax[0].set_ylabel('', fontsize=14)
ax[0].set_yticks(np.arange(len(x_lab_single_plots)))
ax[0].set_yticklabels(x_lab_single_plots, rotation=0, ha='right', fontsize=10)
ax[0].grid(True, linestyle='--', alpha=0.7)
ax[0].set_xlim(WTP_X_RANGE)
ax[0].axvline(x=0, color='black', linestyle='-', linewidth=1.3)
ax[0].set_title('Vaccine Not Available')
ax[0].set_xlabel('Willingness to Accept (WTA)')

# Add vaccination condition legend
ax[0].legend(handles=legend_elements_vaccination, loc='upper left', fontsize=8)

# Plot the filtered WTP and their confidence intervals on the second axis
ax[1].errorbar(wtp_vaccine, x_wtp_vaccination, xerr=[results_vaccination_vaccine_filtered['WTP_mean'] - results_vaccination_vaccine_filtered['WTP_CI_lower'], results_vaccination_vaccine_filtered['WTP_CI_upper'] - results_vaccination_vaccine_filtered['WTP_mean']], fmt='none', color='black', ecolor='lightgray', elinewidth=3, capsize=5)
for i in range(len(wtp_vaccine)):
    ax[1].plot(wtp_vaccine[i], x_wtp_vaccination[i], 'o', color=colors_coef_vaccination[i], markersize=MARKER_SIZE)
for i, p in enumerate(p_values_vaccine):
    if p < 0.05:
        ax[1].text(wtp_vaccine[i] + 0.001, x_wtp_vaccination[i], '*', color='black', fontsize=14, ha='center')

ax[1].set_ylabel('', fontsize=14)
ax[1].set_yticks(np.arange(len(x_lab_single_plots)))
ax[1].set_yticklabels("", rotation=0, ha='right', fontsize=10)
ax[1].grid(True, linestyle='--', alpha=0.7)
ax[1].axvline(x=0, color='black', linestyle='-', linewidth=1.3)
ax[1].set_xlim(WTP_X_RANGE)
ax[1].set_title('Vaccine Available')
ax[1].set_xlabel('Willingness to Accept (WTA)')

plt.tight_layout(w_pad=1.0)
plt.savefig('WTP_vaccination_both.png')
# Out:
# C:\Users\ry87\AppData\Local\Temp\1\ipykernel_26648\4292456425.py:47: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ax[0].plot(wtp_no_vaccine[i], x_wtp_vaccination[i], 'o', color=colors_coef_vaccination[i], markersize=MARKER_SIZE)
# C:\Users\ry87\AppData\Local\Temp\1\ipykernel_26648\4292456425.py:52: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ax[0].text(wtp_no_vaccine[i] + 0.001, x_wtp_vaccination[i], '*', color='black', fontsize=14, ha='center')
# ...
